# %%
# importing the required libraries  
import cv2
import numpy as np      
import types

# %%
# converting types to binary  
def msg_to_bin(msg):  
    if type(msg) == str:  
        return ''.join([format(ord(i), "08b") for i in msg])  
    elif type(msg) == bytes or type(msg) == np.ndarray:  
        return [format(i, "08b") for i in msg]  
    elif type(msg) == int or type(msg) == np.uint8:  
        return format(msg, "08b")  
    else:  
        raise TypeError("Input type not supported")

# %%
# defining function to hide the secret message into the image  
def hide_data(img, secret_msg):
      
    # calculating the maximum bytes for encoding  
    nBytes = img.shape[0] * img.shape[1] * 3 // 8  
    print("Maximum Bytes for encoding: ", nBytes) 

    # checking whether the number of bytes for encoding is less  
    # than the maximum bytes in the image  
    if len(secret_msg) > nBytes:  
        raise ValueError("Error encountered insufficient bytes, need bigger image or less data!!")  
    secret_msg += '#####'       # we can utilize any string as the delimiter  
    dataIndex = 0  

    # converting the input data to binary format using the msg_to_bin() function  
    bin_secret_msg = msg_to_bin(secret_msg)  
  
    # finding the length of data that requires to be hidden  
    dataLen = len(bin_secret_msg)  
    for values in img:  
        for pixels in values:  
            # converting RGB values to binary format  
            r, g, b = msg_to_bin(pixels)  
            # modifying the LSB only if there is data remaining to store  
            if dataIndex < dataLen:  
                # hiding the data into LSB of Red pixel  
                pixels[0] = int(r[:-1] + bin_secret_msg[dataIndex], 2)  
                dataIndex += 1  
            if dataIndex < dataLen:  
                # hiding the data into LSB of Green pixel  
                pixels[1] = int(g[:-1] + bin_secret_msg[dataIndex], 2)  
                dataIndex += 1  
            if dataIndex < dataLen:  
                # hiding the data into LSB of Blue pixel  
                pixels[2] = int(b[:-1] + bin_secret_msg[dataIndex], 2)  
                dataIndex += 1  
            # if data is encoded, break out the loop  
            if dataIndex >= dataLen:  
                break  
      
    return img  
  
def show_data(img):  
    bin_data = ""  
    for values in img:  
        for pixels in values:  
            
            # converting the Red, Green, Blue values into binary format  
            r, g, b = msg_to_bin(pixels)  

            # data extraction from the LSB of Red pixel  
            bin_data += r[-1]  
            # data extraction from the LSB of Green pixel  
            bin_data += g[-1]  
            # data extraction from the LSB of Blue pixel  
            bin_data += b[-1]  

    # split by 8-Bits  
    allBytes = [bin_data[i: i + 8] for i in range(0, len(bin_data), 8)]

    # converting from bits to characters  
    decodedData = ""  
    for bytes in allBytes:  
        decodedData += chr(int(bytes, 2))  
        # checking if we have reached the delimiter which is "#####"  
        if decodedData[-5:] == "#####":  
            break  
    # print(decodedData)  
    # removing the delimiter to display the actual hidden message  
    return decodedData[:-5]

# %%
# defining function to encode data into Image  
def encodeText():  
    img_name = input("Enter image name (with extension): ")  
    # reading the input image using OpenCV-Python  
    img = cv2.imread(img_name)  
  
    # printing the details of the image  
    print("The shape of the image is: ", img.shape) # checking the image shape to calculate the number of bytes in it  
    print("The original image is as shown below: ")  
    # resizing the image as per the need  
    resizedImg = cv2.resize(img, (500, 500))  
    # displaying the image
    cv2.startWindowThread()
    cv2.namedWindow("preview")  
    cv2.imshow("preview", resizedImg)
    cv2.waitKey()  
    
    img_counter = 1

    data = input("Enter data to be encoded: ")  
    if (len(data) == 0):  
        raise ValueError('Data is Empty')  
      
    file_name = input("Enter the name of the new encoded image (with extension): ")  
    # file_name = "encoded_img_{}.png".format(img_counter)
    
    # calling the hide_data() function to hide the secret message into the selected image  
    encodedImage = hide_data(img, data)  
    cv2.imwrite(file_name, encodedImage)  
    img_counter += 1

# %%
# defining the function to decode the data in the image  
def decodeText():  
    # reading the image containing the hidden image  
    img_name = input("Enter the name of the Steganographic image that has to be decoded (with extension): ")  
    img = cv2.imread(img_name)  # reading the image using the imread() function  
  
    print("The Steganographic image is as follow: ")  
    resizedImg = cv2.resize(img, (500, 500))    # resizing the actual image as per the needs

    cv2.startWindowThread()
    cv2.namedWindow("preview")  
    cv2.imshow("preview", resizedImg)  # displaying the Steganographic image
    cv2.waitKey()  
  
    text = show_data(img)  
    return text

# %%
# image steganography  
def steganography():  
    n = int(input("Image Steganography \n1. Encode the data \n2. Decode the data \n Select the option: "))  
    if (n == 1):  
        print("\nEncoding...")  
        encodeText()  
  
    elif (n == 2):  
        print("\nDecoding...")  
        print("Decoded message is " + decodeText())  
      
    else:  
        raise Exception("Inserted value is incorrect!")  
  
steganography()
# Out:
# Decoding...
# The Steganographic image is as follow:
# Decoded message is ¢êÂØÒèò@Òæ@èÐÊ@æèÂÜÈÂäÈ@ÌÞä@ÊìÊäòèÐÒÜÎ@îÊ@ÐÂìÊ@ÈÞÜÊ\@¦Þ@âêÂØÒèò@ÞìÊä@âêÂÜèÒèò@Òæ@Þêä@ìÒæÒÞÜ\FFFFF>|à-c¹ª.£RÈ\í5´ð\7À<qº¹²sxÖ¯^%(¼Ç[Û?M2*èGè§²m0Ñ0ÍØù =Ò3EQµzç>8úCÍ"ÛÄ¢h¿Úí8ü=.øp	àð`é>ÈßòÎeUÍ"(ð¶h{¯KÄq<E=¿ÛÍøá/-Jl½¨WÕ[@Ù¹)É,É §Ð®c?;òÉí-*f§c¥Yãº¾Ö7¾=DJåh¨°
# ö\Òw,²»HâWÿu^èÕÆ1£T¨LN"h]ô:DGùÓîµ0ÁàÄ1Ç¹%(Áüç.U9³âcLây½j1õbJÐ·ÔÓ´ÆGéNÛµÓàÿ¡LÆÏ¡¹,ÍªîW ·¿ûîZá{2ÜÆç¸ò7íG£wö?	]ÿ®¥<=$³éKËË¾@=w
# ûâ÷Pvø³VJRÛØ«OK`É£ $EI='J8`ÍòD¥qá¯B
# ."¾3¾ÿ®¢Ëá{»¿/P³³ø"Øy°Ø6Ó øÝyÀúâþ¨wòÉ
# B½£b0^Ðù5~54|ñVg+^¨Yx»ÁV.ÏLà­¨yQiñLÿ.R¥}ÙMÏ£ti~^¨ðôìäãNØhk¢nlÛù¢¹ ïãåÜG+%1>E5Ð'¤©¼ þÄBYQAØ&	ïmMXVMÈ2#ü7è@+6Ðb9"Ï±
# à84CÌ«·*ª°ÂÄ#Íà×9;ÝNªïIÚùt­^»Ò¢ôjw,#¦>=Eã¥X9æÔ¨:øÐpk¬îI+i9fA²ÈJÕ6@Û@¾:Ò¿ÚQhòÕîGÚ>ÌÎÛ¯ë¿yµKÜÈì9.}õ|wãKÔáx(áÈ[»hì[$/em48ùÁýj,©DÞkàÜg×QÉ^8¶Ç9ÉsQ.fþÕI5êXÎ=%á`tzð{¿ÁS¿Á>ª¿Ç¨fÄfÀhJKnéye× ØcPÀÙ`
# 4È^VZ=l¾|ê½jÈ]&í¡#¶íHåZd_÷°×¸SS×ÅÜGï¯.ôÀílÕEîô4ð05´ñôÚà$}Rh^!ü±©HëÜpë§Êú ÝdAyÅöØ¾n;#Ð·®±RzmË;wÇy3imJ¤î#úÉ'Úè·Cûð$¾ó,Ò8Ma»ç%xqÖÑðKPºcØ ÁwÂW«Ã7;1r=2º£ÏLÇãO¥°ÿ9íÒ8á!fõh½$¶iXD0&o^{rê!¯`ö`5åKt¹OÇLëS¢!hÒæc½$a2¹Ki<~[ *Ç	±Ô¿|4 Ä]"ÇøÈI°õ`8SÕ^6Þ3yí:ÕÖ@kÖ\F
# lV©éinúÕì
# l½àÍzú·¢«
# @Ùým¼¯ø³æþ&ÅÛ§ÆË=\o"Òièüâ§7å£
# >;0Ýð
# ým<GºÞI7ÞZy4ÃJT¨h°>Ù]"WÊßø7z;±;ñG~áR>õ/-õá>sñ,£¶îûN½âÔî
# ?ÃÊWp¸È®7düá¶ÚqÆ|MÛ¦#âAq6Ø"Ú}*:s#êg
# !#Ð­§ÿüà´ÃÁ*ÿø»£¶t¹~Ã÷/NÞ4Mo¶_´±¡t¥Á.ö>Ò?Ùõ¸rf+Èe;o7±ÄzJ
# i+IÑik"áÔþû8Ç"¹yöiüêzøR©õ+~`!Xé¡nr|ÇæiÖÖWpðÑÂ»U®9¦,äV¤±ægSv>kNÎÒO
# Å %XgOÀ5æñ»É;tLÌ+>zT	áÑò(²
# gÉëòV\ðæê:~õ×ýäkÞ	¾ÆàfÇ`9Ì´1åA¸±uA¯Lxà!ÈlXÆí9Qú O4CYÁ2ö¾«ù¡ì%&ô«¿ìÒ±Ò¨G9bt©­¬×8ß«²ï}Ü¨qn!ÕET<×NÕÄ¿T$aq'tiñÜñHÊÀËä´<Çi#;_%%èÜmB/a>Á¯R½¥	D{V2¹ÜÑÔ&æ²Og,J±¹èyþ4kYÌÔn.XGÕÄ`+¸bÔÓXÄþå0'°èC5tLmQä?ûxX-Lÿ4ÀMºây.«F¬gï:M\MXS
# Ôw/³sJàä« ò§ÆºFÅß_VZO--,{E?XñúYfÂ1Â§LËËn*ÉÞtÜ-³"®N9YÈ~¼YùÖçç/¸£×ã÷NKTSs`k*UHN¯è9%¿rHw+iê*½¿ðÚ?(¡ë£7RBûsÛ£»c
# ÷¡`nïb&e°s@?æýW¶#{(§þqºÃ||n-¢§öTpe«}E'Å
# ·ÔvÆ&¥zK@üO&:«&Æ}#¤1ÿ­l,akÖ©ß+vQÊ§Å)Yéáz/¸?³jº[!¯Ë#©Õ|¡Ó¡î/3ÆJ£ÒEÕ^è­§XÇ>zKiãÉ!¼]ëË*»õxGT¶náª¸WÅè¨qýVCÅç8éÍ¶,³±÷®ÀwrãàÆNÔ:Þ#ë'üÌÿLq¾ÅRúZ¤ÄÞóÈÓlZÞ@6¦Ðw^íëdkRØß¯½ïK¢É1ñÅùO]?F>ïó(n$#Ãö1%q¼/¶Ïw lÝ`ú~dHKhIb{ø5Ã×öQ3e´³²2ot8º§Uýú¼L:(ÜIt¥	w&±IÍtkêDãË+Éº ¯[þÆê8:<ÈìÌ}ä?ãÐÄG5¦jJÈänsáÄ`èxÕµ³,´w ÔLo´ïùúäj<òøD"Á1ÏÜ³±ÒIjHQÈ3ÊNxðÚ<â°8$	Ð^@yÙÅVún$EÆsþÅÉ
# j!ÍõuJ×*ÆÞÆ0<®BþS§zZ
# \bÚFþ^Üi"¸¶ö6XümÎçÒ¡÷>:1 ícë¨²8k-ÿÊ¢K?|%øÊ²; ¢tPÃ{¤+âõC pr_X+²G"WËL	¹DõÀa¡)Ã^Û^1rÎÃ5@ÜPîHÏd¹~
# ò2TÐ!;CW§Å `pi¨@M²*×÷~Vnôù>b©bßÃÃ··_g'5+ªáÏÌÕ>Õ¢¼ßSü{+ÎmòEð¯SyÖÄ©?°úé(§Pwº©.P
# FÅ=|ÑúçuWjÄ@X§]"´uØêà
# À=³«d(/p_îFxßµ´PSb´÷ç6¼îK(¤«ÝUZr
# fûkFLüàÍ`@ùYøÓV0§=ð.ÔP6÷ïÒl«IÀ~ W`àUá±qÃ|NË<M´àhn58^ð­ÓøKDc{&Vhq?fÇ1ØpÇ<ãð­¹Ç¢kl:rc²i$ý*¸\^s M/ÓÇ3]ÁÍ`ÈÃ)¯Õëë4~Ý#«Ø"´ëeoNÄwZÇ;¾zÀ­îæágGOHTaA×üþ}[vÀ×2;|eH-ÌÃ°lDùy¢îÛ°QM±¿ ¿«w:ñr "
# b©´Îß°:äXµCBéÆ®¼&?³õ5bìeÅYðºÉã°"xYú¢ÜëÁOj) 2ðPyej?4ãó4¹7BÒñ±2§ïª"É`FÞfZvæÛ¯ÁX¡Vâ4®õ¼)F²gaþ¶È-&öJ³r]hdüÑ4Öw;ð ,±Ù¼×z;¥;ÒJQ ?;c¹a#lWx­ \ªnúSq`@U6ûÎ·ÙLE&­N{H«Áä1FóXhåRæôdO¸Å#Ø°/Ç°Ì	º¾ËÔûýsj
# lö7Y1úa£dù¤±§1üWG*¹9Õï¨ rÆ&Ô°aè¬8Ìÿá)6Q -ë·[Ë³ºÒG*iéÆ,ìSÔ4Ô½Ì¼ÏIUÒ4Í/L6i¯¼úÓGÛÌsÈà5Õð²#ýÚç0-Iµj!wøMWä-æ,¾Ü]·j4ÀßRç\xáÃp5déT_Êi-|ÂóÊ¢04òv@$Týe¾.t&{ãæ
# sd¬HîÅ´XRÞi®ÅÅó4D¯4¢Yø=ÔAQYM#|-FÜìÐØdõÜVI:xi_ìÂ·ëýÎ[§6ü®íå0®Úße0áê0ÊË¡ZÔ°ÔÇ.${f>ÁwE®C_~$ÎìhÅ3à*_w?-)Ý6«×@ìç@.44D±*"!+Z[ uäÎÞ±îaøô¹.¿Í¦SÞYØ¨<KÀ¥ÚKi!?,$e-â+ÌïÞÖk¥mÑh_uwê({4AÑ3:ënêÒ/¢	H,fsEIÐÉW0äA°Ubejåÿ9Ë½ÎKpFT|gàºpî§èË8Ý°ÖÇAýid0_×Qßà5ÜðmbÏã]ÒR	É*©ð×¡Ù¥ï 5ßöEöâÅËjSêz/1»w½aû|)ÇÓ»ôªaºÀäÂÖ+ôÓ¢ÕÝc¤kÓ¢oÇ¿èÂUç¥Â=³e"¿lÈß)g)I28Â¿Å£Ûm(`£@Cüôo+ãw±ßUÀ68oä'd{9®A'¿LxaÜ¿ûÂ
# pdãàÀÑ©{ê«:aÄÏo^7Öâh­ÏMå²!Zç¬våFõ¿JVãÌøofPLlX¥Uàx?NÒIp?áÉ)2¿ºýS*Váq7¯z½Î_-L³«ìÛ½ê¬Á'f¼fR°öNçxbL@Y@$Àâðè	?A'E2Ý[+Þ$p¥º¿MiVq\nÄbâezæZEÆ<¤ÛªÁ5<rHxk×ºçÉQÚ[_q9¶þjª9FZ¤Ç¥z¡2.('9½y>ü/Ì8asã%C6CÉvè©~¡¨ö¡lÖ<æÙÈáËïÁ+Ô*¡Ç>+Ic½>°Ãc¨´dQT`vÕÓË)às
# Æ`&IÌzKÖ©ËëØ.ÿ$ðc#úÂÑ#ÃÎëÝ¶ä³eY©ñ!Á>äâtâ§ûAZº
# 08¤Bïþ[Å¦eô¶ù±k0Z'ÖAþµË¬MÿYCOîõ/wÑeÕ×Z¥mQ°yñå7Ø±p/aëÀê'>kVcmëzWY\w'5¶ðùH0(,tkQéa_t{^jÖ$ÊµIÇc#göWX'¶ Û¦~»dÖjð?0ÐåÔÀÓÕOm~|³ÞJA»^§¶ÐºÔ`6¨yå*®lÞÌÅz¿2-µ£ß#Þ¦Ý¾îI"ùD"rAdû¯É¤ÄAc®'þÖ7Kõ9q)Þâ¼g¡å44HÂY3S®oÂE$F°0ß9Ny|f«ËµoU¶"_)úSðhòÛÿÞ!õýÈ?Üþ:"°Eá@öm* Ãô!QS_L -½Í>è$>w¸÷'¬ué5Â¸®}8RJ¸%þ$>®;®uÀÞ}ñ&zÑÉÜ}4eéd/â.ûB­R 'ÃÈGú ÈP	Ð²s¦"HnÇÓµìgYÓ*Æ¿§Êk)ÍuU4±Ñ0C9B®@ ðÁxâ%~s|-eA$óèVÙ¥|Ê]¤âKtê»q`'Â#Ð&e»ñ:üúÁë¨
# Z¨gBgáï¬|J*@³Â8JlËa:k 		§Ñ¦	z74MÂÑ°$ÈDv;
# T~psQ=NO4É~Q=gd\¡o\ó¸ä,½¹´ÀÛÌ%àzõrÃ*z~ð­°mÙ{Î¥¨p@u¶c'ËüÐ 8ä
# "	¥ÏH®)©$cªªßû¢IðÓº¶¬y4DQC/3&P\`£kÄcxk½§¸rÏ,M|°göô[²/Çû\vÅ+Ô¡_b<(LY\peYa=ð%+ëªe¤;J$Ö Ú¾Â",?} T8Ä¦É-PDx,iT·D+´)R@»Wãè,r Óã°ª¹úÈÇ§V	7À.¸É)ÌE¸ä ½c.p/÷ª¢?à4´=ª[Ê°á·- *e÷#)¡^nn
# ¢»æÍbrLÂØæ#àÅÊ·Ú§`&Àºøé;8ÓCjL%òÜYhæë
# ù»5B|±I$]-¾O&0]ð$(Íj¯·¾daïKí6m2Úý²«uvJÈ¥4¤Óv-Ð+ûPØùwÿ(A¼r¢ÃÚöbkñÀ®ÇÊ¯æ**°àú'âVWÈµ;1Ãs½Bw³3ì@&!öMRÅÖMt4Í¬phj¢Ó-µ1Bfy5ñÆ©fÍd6jÜ
# 4TA&]× 7¼nK/x'ÔçÑÇñÄ	%®ÖãyÇâEÙQÄîaº·Ë#»+ÙÀ+ò(3²6
# ~¦0Q}â[?¦VÝèN§¾-³@O,ßG°.>M;¥2&	U6ÒÈ¤*(-Eõ<:a®~¥RÑ÷ù±þIêIN¢ÆÛj"± =&{pk¶wç(dó@8þ"­GjHÁ?ÿôlI4±ÀCQ4ÁLÓEèÜ@¶k9EDqr7Á¥U1¡¿Î¹ø=>#ñp7OÙ¥ã :¥¬p=Þä0&
# 8|­hxÂ½S"øçaBÂp8{.BÔÚ¨øÚ¢øÞïC8åY¢:/¨í^í£×/Àòô:ÚbÀkáþ)@	òLµÐ'rì°ÑÈ5#xÀbdkv&è-CøGZåirpÛxò9ÃÞÔÙ>¥åÜE9¬ÄºÌ%ÆX7XI#å¨¢ä¸Æmí»ÔzÝ©ç8¡qAi0ä8-&Æ:¬2UlÓ+ðÝðï1íKÄq²â£?*A8üöuòAmÑK`§¢©Ãeµx8.l]ð)ÒÕydC°ý·.Cô¦oTv¶Þ'¶Z<êÍõKGàhô~Mõ&Æ¹ÚÇW.¦9#¹GGg¢DÖjÓöè¦´Ú´j051ÈúV½ÇL©4n{@ç@Ònqtä7ówKB"G?{!&Øàäù`ä¦ Æ:Ø^8·Î-:¶f·Kïô~uÚ÷aGa¢Xx1h8àì!¡Cþó[Ü#fÌî?Ì ÜcòO*EºBLAè@l±*æP··#%*8L:å>WüÀéZ¹FãÍ8ÿnOjÃx§ ¥Kx|1º¶ÆöÒÑ!ÐÌÃ¾Û`ÿv¥qTK"¯V¬×³²¢äáó+ÊÂõ¼Ã*UÙ¼à?1¨vOÚ¡Q©
# êz öOl
# ü
# uTVjV²$l¹jæKÊd×
# ©µßÃ¤Cá¿­ØznÏÅA°mäp¥s¤ HÍ°Ãéav^líGÆß¶Æ°Ý·ôF$®«W5É9-p-ºI¢²9Ì¶¤æ«EG÷üJüÑ50¿	?+V$øÁµif}ãqòxÎì»UkÈûëZªÇó®QB¡GïUBÏjv	úæØÙmioà5
# CÉþã¶Dà®#ÂËö	î¬-æ$lE]VZàÎfxØyÉÞ51TÑÞHáU\»yH£=ÿ¢¤oaÂ¸#DÂZá®%EPdðLÜ,Ñ'òEwE¦àFÎ×-N 'ÁFì*¢u½=JbCÄ{TÕË4[¼.àJo|tv4ÿâÚ¯BÔ|aèóø£ ÷öW±~Ôãú9ÌQÓLâ%«~µ``ö6º¼<rÑ¡-â¢ÌM4ð¦=¬À³Æå³WÌ?+uÑRäÈ?ìÞv'[Jèãd	=¨4ròDí£<=}ó.³ÒµËn7*þÈ	é	RéÐ¶u¤´Æá
# QlküÃÝ*Á(éÏ'ä	£ÌJ¡w "ò®½ºå&ä¿@øýT¤|Ú¡ò±{Ñ¤O/C¥°3¶½ÚÊrF×¨ÀéÐ°3³³5Â¹ü.;R®r-2@ê( ´À£{8$
# ­xFÞ8ÓÓº³¿þÚ,X.c­öý~MAÈ0R¼;)vöÜ?×`rAh3¼§íö j?r\g/ôÀ#t,S´ ¯²ëpÚÿðsøÖ4­}µV¸[$ÛÌ¯îæôüZôe.!ú@Z>7¹ü+´iáî¦ðà1¡R®Ü¦^ÄÐØ 
# È9!ê?Àx úiM:¯,odöÜ %-Ú¶Þç+[ öÃOÅ7åÐjº²L´?Ç¾ehG;Fd@@/P.7	¦a_üÍ
# øJëIÃ¶Úm 7T¯%ÜlÇõ]k¡ÂqSsåúÀj»_¸°Ø7@vv5Fq\ÉPiÍö;Õ9Ù¼ÙÇèzdbr$ñ£¿¯xê­èiZÉ´µz¼HòIy¦ÿiJ:H6;²85íñ°õQG.ÈyÂìzá»ï,T¤`®ùÒ· ½m×Z-vI4WA,@R¡ÄæV3¡ú@l³6
# úNßÇa·þÈñûÉp93ý¡p#¶G;b1TVvÞâÔzägÀðÎþZª´*
# §è¤®ð6¤Z-[Ml[¸ÌK¤BÑþr,¸GÔ3éG$¡'ì³T	x·"xm1hbÜäN=ÎV<°2¤/ÂàûÍßYûeVª!¶±\Wy	Ï´uï$JÁõ¬¿tÂìÆi°%4]ï®$M¼hµ[0*rTÞfî³·ôoÿ^uþ´t|¦Ñþ1õÎÌ0l"Ó4k%°³([JÕRqÏ	aÌ,ãxaëÄÚkÙI­Ð4AÄH7óÕL¥1òH-g-Aä<èD¨êuÁ]½ó u® j-RtöÀ
# ÿãXÁdxHôfUã&ëµ÷mJ<ÕwÐSÔ!Í½*ÁCç9nc×ÏxÁPØÀj!ãô ¶8p ²TOû`b ^+>0½y{°àe&4'ß«nj~	O¼ª¿áÔeaW\¶R9Ôáa'ôtHÜîyrÒT®v)-Ë­á»öP|HÁõg,H
# ¨ª?%E81s9^Ó}õÍwh:]1Uº¯$Ï<ãªg«vV{ø.û¡*¥F¾´M]<0?¸6J6±Nð|	úãîe
# {	­B¢-ñèÇúÈsYxDB1ýNårÔ¥\ó¼¥ÂÞW¬JNÅÌÿäà)'°.%ÿòÂ
# sf3(°A3wNà=kí4TvØv'¶S²¹ÿc±I+qc Ë(fÉüm,ó`#e¦¦bG_µ=e÷ØKZy"Ê:Üù!EçåQp)¢þpL©oµ3»e4Ñ±'q:½%4;®HUs^M+åx¤Á`B9r½©ãd<>Ý2JFÁðÎ>Æh_)ÐlaúòL½JEp!à_*FQÉ¾OøÍÛöÊh)9)÷VÀóyº¸µ¥·¢ïÇñDü P	2ìcBJäöIÎÃDúïCn$ÏãO rÊ1®Nç2NÄI´$yt9úTXÖr Y%8²½ôÑy²çÈÙÀ(Ôà*Å¸KbKMÜÕiáFDtÃÛcwÕªpIªÑ*Y°¿åÐcQw2j¿cp]Fh¢f.I¬¸ñ àäçî_9fõl#³ôzª5¼kû27Îx×¼.wZ÷Àj¼Kýà
# j0*@ìc|áë;êªò$Läd¢µß]ñGx¤,¾~¸6þe4MÒ¦I£ósÉÄ?YaÌ;%ü<XTúÛÖý_äHA³(ËèÐBv¶6xX!çXq|f-j­VÔ·ziwq]PIE;(1xæïuÕéIË\m7© ÜÐ
# }Hü+òÈ¥FõLhbSX"¹6ÇÀãã{Ç8ü¯Ïõ£®É_h.ó,`péï¶kUÅT²hVßïÜd;96¦ÑkGI4¢ÀtZÉælL¯§±³®;{%n]Ð~¶x*MzKìä`OÀ´ÆØbÅÌ¬¨¬¡JäNhÙö8?}@eÏ|Ñn2 ©¨ª¥Ãì9a$¥Ê2d¿'O>*7¿¶ÜÕ­È¢w¸1£ÔµðMh<zY{=f¢¿/3É%ÿ-å©®¸Al~Å¥jUUU¥LDàÞ
#  ª`{í]¶à­%B"Õ.mþJÎ±qÛ\~Ê	¨c^Aù	ñr©7~RIlmX{ UùÃDuÚ*ôäíâQbIãÀRC»µCÙï^þ=	ò6Ñ`(ú¾ìÌjä?¬a½gq
# cèÉ°s<iÜüüÊêàÓÔª ý[)c)@óý¼
# Û4dõ
# {¬£ÉÏ{wÍk;¿ÀéóýnSº¶Ûm.tGQ
# ¯E"¦É­iæSÒl­<¹Z ¸èÐBPªÙ¾+øq/ ùÔrPÖK×²W &ã´YÆ#ÇaÃsxÄúw^v×¯3Â-¨u)GÉx"Á®Ê§i<o¤}K°ôI¶Uç
# ³ÿð-­ñÛ?U²bº°44*S¦-"ÝþµxzçÔ´Þél2x¤v
# K¸Ä¡`b­5Â,þ6Y+´j;6J	<XÒw¬*¹$ø^fÚÐèmMù\W3¼¯÷èâ(u×à h° n"Dõ,`à~ø¯º¹8bß¤[IXNF~Ø§¤P'öÙ¥nò^õ÷ùCÉ0IãdÌ¼©Ú¹c÷v·´\¤¢~±>Äfu ¢Äù3.ùÂñH¼S\ãëm¡yµË^áÛR ?l­® Âíæ
# ßÛ8Ú?Qjh»GÅºÌâ©U$JôzÛWbÅ#ÎÏG\¯'[uÉ[àCý]acæ¼3ö#É"Øu8^¡Àãñ6.G*­Å6ESkOXüRD/ùÅ5¡ggè~"ôsc ¸*­WCY~°³@ë{iOm!u¦çnÀÙ@È¤éJò1§¿ë¨@øàpáÌÊJv !¼ogU¤`8Ôî7ìØ'OqÇÿþÚªûtCõB+MímW±cR}¼$ß¼\L¨ýPòò
# &·=v0HAÀî[v)¹{:r§Qà%KÇÑà~üðtËÖ¸»ÖPÌ	èÊÖ8-ºÕªCÀ¶* Gn_Ão±¾û¼pÑ¶YÎMØm\v6D£p:O?=Ð	u(°¯ûm~:(scËð³½­P0ÓÉí[Rº+¡8£Ðµ*³ðænn«é¬7Ã?é7ýb Oò0FFW7ÐPìd/Ð­¨~Ï¶ÃUþU[d.r¦
# ewÇ8¨VäÜÏ¹c×72rDj¼¿k ²æ¢l$TÚ\qC]É>oeäØÀ7ßéìºíKÜïjN'w=	J zåOéü¹ÞN7ü~MZ%Sì^úN®ñ íÌ×ðnOîÌé@4/Â²ÛÎÚ8Øµ'nðío>u>ïxx³ÆÎøÑ;sèà¼¦ÕjsÕ+iWÞ_Ê=Úç´iõj@§±9ÀãEÃÄÄ¨¯>_ÈÐS§*Ã$+/LõiÿFm¾øÌÊË¼TI\U+eLëF¿¡ø*Ä£rDo¾2Þ´K%x6´ÄAÏ¨k1Sà~ªÚ.Ý6ÅQðã¥>º«×ÀzAxGA.µ|ücø`,¸RÛc¢,Ñ30%Ïj³öpé¸ý³ÂÜi?ýPk¥øÍaTARcÖ£ßÈN9é1D}Ã]¬Àõî5cÌIaà¨Ð#ÏN¨ªñ![?`2I¢4òG`ï`º#ü3{:
# u­õNJÕpN%ÿ6°®>¤"Ð¿m¬kú"c_Ì¦¨MÓv	Ò\n/É×¶§$Ö«u&´BPqiöø?"ÎÑßFÁ¡9äÿH§èt+tÃ¹Ý¹ßÂ?
# ó°º ×­!Éßî¿åålJ×.ÙàLnlVX¿ Ò½ipÚÅzþªY¦P j~]tý}' ,qÀíþl|VÕE.Í©I:ÐR\xìý'ÿ«,rö.à\RÆK*±òt\äÂ@ò¶ÚÆ¯ÔÿºÆ=teM#ÿ³vÛ>b­ÄÍm&oFÜæ1è+y¿lâ )²Õ×éÛ¶©#$­ªòÑnËE§\0n·Æ¿NÉrßÌJ;¾ïÍq*ÿ?à³YË| D{y8@®®Ò1a´QÆFWï©¡À¨Ís§¤êlÍL ÓäJDCGçró©yeãóÛqþîÒ¨¢)¬¡I×FëSÕ>ÃNOïPrME?q@óÙ9lËÈ(/§NöàìUÀ8¤ÈÃFWen{!ÚªCrA
# £mmãËÅ!¡À¯8]J)«¶Ç¶Ó(,ûë£Ñq_gÿGþ;xrø¬zá@+¹[ÏËlÔðss½Æ2¼6nóÓ¹ÎÆÁ!JYß/ñ#Á<¨N¯¾¾äSPùyW7í®äì§mV±QÇ·×ø³Ûñ)Mn¯k§W{ïù\NüRª:ä%E6.i¦kÇ|b
# Úá6ß8-ìõCòªéê\);6ÿøâåâÒåÏíÏÙª(2Á)G" ZèÄRÂi\!Ú&æGö~õ¥wËu×ªàKh&ßÝõ¬¥¦¨q%+<hô&D&üx¥5°ÙÄV`Þ+O_kæ«#4%U¤(¥8à6ÀGKà£üÝÊãÊÔã/82ã$JàPþ¶*Oü
# ÿÇ9mR@BjÔBû.ND
# ºL¬ÞuóÞ'ù¶¡K6þj%hô³^ÆpÃ/ïè"©2ðA@1:'gqû#ãXjc<j»ïÌz±º&)'*AÙÆ3à)_Ùª<¾â©BFfDÌÂ- ëAi!V!l[aT-#ÿOcÄÄ{
# o¯U$<cS¬%zG@ÚÕesóÒ±Ðmlµ".á«³À>À,«DFÅàµô¦U·IÁH#c§;Ìf¹'­,*m<|®`ÃÂ2wÆipÇ
# ïÏñ}ÆÏ$¬8àª1¦àÛ'ÂÁ&rëM¶8£%ÉºÃ+b0_¢Âi`Pbõ-4qdà¾úS¥ãC
# Ê89$ùT½©ÒóºÇ¤£þÿ4¤ªþáõ ²5l-&ÓH×°éNðH_$ÔG#q±-'(>G÷ÄzWUÔº2~¿ùÆÚÃ`ÎZf-_¨­is}¤__ð8Ý_³ôè*'ÖØ]¦<tËÙu¼LÇÔÛR&6Ð½*g1¯>éÉ¡åÓiazz*×´ÂòÏdÓ8Øí±ÉdW!R`sá?Q½â~Ø²
# B)Xí	Å@ Çêã.¥eu9a§ÖÙú¼aëEwÌ'ôqúYáËÄJbØ`Atìtj_ÙlÆ¤øI'ÞÃk&ÕÚÿÿçy¸ |ãaàG×8hYÀÔ QìF½9lèØ×ûüPX ºþÅ£sß¯gÉiá¸üKqsz[±%N?å»;¨ý[¸¶xÔ:jÂ½EiE6ÁãLiöC`n³ÁÕÎFõZ)fÚìPNiÿµ.Ãiø"I&75¨lõöÚ (?Ü[aáâÇÀü'Pr°4´ZGÖÿ(¹æÎçÂ¦ªJLRâê#ÝåÁ}*àUl/ðáþ¥¤Ù+¶o¶í¥ó>svO»1Ø_±Õý¦ØØ\­ü%DK½|«Ãò¯Ê6\ÿG|"fÈÚ9{}	E¿S}Já@h^?À·££ 5¦:©8«¦|,UºûH`[lÄ	CçE½lüsàb9{?ØE_!H
# VuûñiîdA¦pØ1®8³ñ`¿®T4KU©Ç	Xo·q¬ª½ÕbpóÏm­fÎÇÂ%ÉÝù%gË¦fg¥Cå¢ºº&I½"ÙèOj»n¡C%vCRk'nm¯þ_îb8^%K;gµÈ¾'YæäË@Xò¼í~00Vö°Ýãû<0:&¦@sÔ¶ÒÏ æ=Û\QÄ5VY/ <­i9uìA7ng«ãêcÖÍ¸-®·#{GòôÊ!_
# ãëù~¶¸ãÎäÍæòrÑ÷{Mµh·²5M0ÂúÖOÿFôðê±T«è¥ÃãÎçÄ>Ñ^ðmÒ­½·1é{8­q¡cµ{°)âðÖªs¹,§;ÜÇÆ>Ô5õ¯ýQqÊ°ö?úÑ{aS²#Rq8¥ZIÇ'²ùóxª«ÂBÃ´3ói}K³éæ¨Îù¶ÃeT­B¬ìFÚÀì
# ýR¼Ó9	û+ù·Îß#ábÜ4ýyxên;m¹1CGÿiÅR¡~qÚÓ1Á?DlÌTGAYlëG	É»¼øIì{ÀþõÁ=w??ùH]^íÔØAÙn#´ª]ê@ãZ;l	w#Üåkôìãn9$Ðl±-­¿[Çr@D°Çx£ñ	(Bð±­w^¦¤ÏÀyÔ\çR¤û"þóý¼ËÔë¼ÔíÀ
# ëxi"§«> ^g½¿PbjÉÁæ}O#X*{Æ8VÇÚ PØªKÙU[:uß|ÒÀì]î#Î!Ô£j6ÐjÏ6U`Nym¨q´m_sá7©àÕy÷n°ù\Mg9ò¨£Ú©dÂfÕ:Y\ ñ6@ûµ©°#"ÇÇ­áh¢$VIÄêWÎhï4!Éhå±I3g!©ÒOÚÐCT»û¾ÄEH
# ­»T8½p\ÓÍØc±è<lÃÞ/Ók]¯j|6Ãcæ;m83Á&ÈxX¼Ó[·\sÛt Ã?D/Qñë@LU¨µ1
# ZßýUÊí¹ìHøRÇ%·rÉ÷ùäÞ#Ã
# å¤y®ôñö¯gì0úòúq¨»=²Ü®sIGj±\ñNÕ©.ÀTÏsj+æØÀù<æëx!}/c$²\/{cÃÁBªÝKVÜõÃøß¬#ÊALcÎç0QzYÐù×@ý2ÇdÛIW;,4°ixßàOÿ¸äxâjÉ§êm|ÙH-Àl,CîBÂusñï
# ®Û"0Ú?_
# ô ÍJÕR5UqÄ´Ý*Sµøt¡´b¯¶i¸J>q[ z«ð!ðó­,Tø0~ã)KäxzYÒäBÇî¿ÝGSdcãÿoD~ ÒÝå÷ø~ÆJåjbÉÆigáÌø¼Ú2§8åëÉ1·YîV]GÁ }Ç÷%|
# ð¦)XÚQ:g{§ÄÈ0ÞÜyËú>¸Eä8âh«¨à+ü0?§Z
# mgÌÏâªâEm&9Ò·¥³	"MxåÍJéYÀÏµ×k`4"PékVË|®©²3VÏez/Q­`1©ûÛ/ ¿Ù·0¢¤¯{{-EçYÈ»NÂs"ÒÛ)=Hq·¤>gô]¨Ü:\¦àì®+'øóß ;ïÖÕñ C"û'ª8¸Û×q
# ºL¬ÞuóÞ'ù¶¡K6þj%hô³^ÆpÃ/ïè"©2ðA@1:'gqû#ãXjc<j»ïÌz±º&)'*AÙÆ3à)_Ùª<¾â©BFfDÌÂ- ëAi!V!l[aT-#ÿOcÄÄ{
# o¯U$<cS¬%zG@ÚÕesóÒ±Ðmlµ".á«³À>À,«DFÅàµô¦U·IÁH#c§;Ìf¹'­,*m<|®`ÃÂ2wÆipÇ
# ïÏñ}ÆÏ$¬8àª1¦àÛ'ÂÁ&rëM¶8£%ÉºÃ+b0_¢Âi`Pbõ-4qdà¾úS¥ãC
# Ê89$ùT½©ÒóºÇ¤£þÿ4¤ªþáõ ²5l-&ÓH×°éNðH_$ÔG#q±-'(>G÷ÄzWUÔº2~¿ùÆÚÃ`ÎZf-_¨­is}¤__ð8Ý_³ôè*'ÖØ]¦<tËÙu¼LÇÔÛR&6Ð½*g1¯>éÉ¡åÓiazz*×´ÂòÏdÓ8Øí±ÉdW!R`sá?Q½â~Ø²
# B)Xí	Å@ Çêã.¥eu9a§ÖÙú¼aëEwÌ'ôqúYáËÄJbØ`Atìtj_ÙlÆ¤øI'ÞÃk&ÕÚÿÿçy¸ |ãaàG×8hYÀÔ QìF½9lèØ×ûüPX ºþÅ£sß¯gÉiá¸üKqsz[±%N?å»;¨ý[¸¶xÔ:jÂ½EiE6ÁãLiöC`n³ÁÕÎFõZ)fÚìPNiÿµ.Ãiø"I&75¨lõöÚ (?Ü[aáâÇÀü'Pr°4´ZGÖÿ(¹æÎçÂ¦ªJLRâê#ÝåÁ}*àUl/ðáþ¥¤Ù+¶o¶í¥ó>svO»1Ø_±Õý¦ØØ\­ü%DK½|«Ãò¯Ê6\ÿG|"fÈÚ9{}	E¿S}Já@h^?À·££ 5¦:©8«¦|,UºûH`[lÄ	CçE½lüsàb9{?ØE_!H
# VuûñiîdA¦pØ1®8³ñ`¿®T4KU©Ç	Xo·q¬ª½ÕbpóÏm­fÎÇÂ%ÉÝù%gË¦fg¥Cå¢ºº&I½"ÙèOj»n¡C%vCRk'nm¯þ_îb8^%K;gµÈ¾'YæäË@Xò¼í~00Vö°Ýãû<0:&¦@sÔ¶ÒÏ æ=Û\QÄ5VY/ <­i9uìA7ng«ãêcÖÍ¸-®·#{GòôÊ!_
# ãëù~¶¸ãÎäÍæòrÑ÷{Mµh·²5M0ÂúÖOÿFôðê±T«è¥ÃãÎçÄ>Ñ^ðmÒ­½·1é{8­q¡cµ{°)âðÖªs¹,§;ÜÇÆ>Ô5õ¯ýQqÊ°ö?úÑ{aS²#Rq8¥ZIÇ'²ùóxª«ÂBÃ´3ói}K³éæ¨Îù¶ÃeT­B¬ìFÚÀì
# ýR¼Ó9	û+ù·Îß#ábÜ4ýyxên;m¹1CGÿiÅR¡~qÚÓ1Á?DlÌTGAYlëG	É»¼øIì{ÀþõÁ=w??ùH]^íÔØAÙn#´ª]ê@ãZ;l	w#Üåkôìãn9$Ðl±-­¿[Çr@D°Çx£ñ	(Bð±­w^¦¤ÏÀyÔ\çR¤û"þóý¼ËÔë¼ÔíÀ
# ëxi"§«> ^g½¿PbjÉÁæ}O#X*{Æ8VÇÚ PØªKÙU[:uß|ÒÀì]î#Î!Ô£j6ÐjÏ6U`Nym¨q´m_sá7©àÕy÷n°ù\Mg9ò¨£Ú©dÂfÕ:Y\ ñ6@ûµ©°#"ÇÇ­áh¢$VIÄêWÎhï4!Éhå±I3g!©ÒOÚÐCT»û¾ÄEH
# ­»T8½p\ÓÍØc±è<lÃÞ/Ók]¯j|6Ãcæ;m83Á&ÈxX¼Ó[·\sÛt Ã?D/Qñë@LU¨µ1
# ZßýUÊí¹ìHøRÇ%·rÉ÷ùäÞ#Ã
# å¤y®ôñö¯gì0úòúq¨»=²Ü®sIGj±\ñNÕ©.ÀTÏsj+æØÀù<æëx!}/c$²\/{cÃÁBªÝKVÜõÃøß¬#ÊALcÎç0QzYÐù×@ý2ÇdÛIW;,4°ixßàOÿ¸äxâjÉ§êm|ÙH-Àl,CîBÂusñï
# ®Û"0Ú?_
# ô ÍJÕR5UqÄ´Ý*Sµøt¡´b¯¶i¸J>q[ z«ð!ðó­,Tø0~ã)KäxzYÒäBÇî¿ÝGSdcãÿoD~ ÒÝå÷ø~ÆJåjbÉÆigáÌø¼Ú2§8åëÉ1·YîV]GÁ }Ç÷%|
# ð¦)XÚQ:g{§ÄÈ0ÞÜyËú>¸Eä8âh«¨à+ü0?§Z
